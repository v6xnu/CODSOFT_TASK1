# %%
import pandas as pd

# %%
movie = pd.read_csv('//Users//vishnuprakash//Desktop//CodSoft2//IMDB.csv', encoding='latin1')
movie
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
df = movie.dropna(subset=['Year','Duration','Genre','Rating','Votes','Director','Actor 1','Actor 2','Actor 3'])
df
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  (2015)  115 min
# 15494                            Zubeidaa  (2001)  153 min
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in ['Genre','Director','Actor 1','Actor 2','Actor 3']:
    df.loc[:, col] = LabelEncoder().fit_transform(df[col])

# %%
df.loc[:, 'Duration'] = df['Duration'].astype(str).str.replace(' min', '').astype(float)

# %%
df.loc[:, 'Votes'] = df['Votes'].astype(str).str.replace(',', '').astype(int)

# %%
df.loc[:, 'Year'] = df['Year'].astype(str).str.extract(r'(\d{4})')[0].astype(int)

# %%
x = df.drop(['Name','Rating'],axis=1)
x
# Out:
#        Year Duration Genre Votes Director Actor 1 Actor 2 Actor 3
# 1      2019    109.0   229     8      629    1352    2272     319
# 3      2019    110.0   184    35     1335    1198     719    2148
# 5      1997    147.0   157   827     1530     378      75    2045
# 6      2005    142.0   289  1086     2044     692    1112    2524
# 8      2012     82.0   320   326      135    1934    1175    1013
# ...     ...      ...   ...   ...      ...     ...     ...     ...
# 15493  2015    115.0   229   408     1223    1861    1801    1615
# 15494  2001    153.0   133  1496     2059     763    1619    1184
# 15503  1989    125.0    28    44     1793     406     754    1685
# 15505  1999    129.0    38   655     1025     112    2164     314
# 15508  1998    130.0    38    20      895     468     753     303
#
# [5659 rows x 8 columns]

# %%
y = df.Rating
y
# Out:
# 1        7.0
# 3        4.4
# 5        4.7
# 6        7.4
# 8        5.6
#         ...
# 15493    6.1
# 15494    6.2
# 15503    5.8
# 15505    4.5
# 15508    6.2
# Name: Rating, Length: 5659, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([5.94568471, 5.78597402, 5.89597398, ..., 5.86731668, 5.77156958,
#        5.78120085], shape=(1132,))

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,model.predict(x_test))
# Out:
# 1.0444246590329513
